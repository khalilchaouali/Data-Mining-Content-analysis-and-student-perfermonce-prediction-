# %%
import pandas as pd

# %%
skill_superskill=pd.read_csv('/content/skills_superskills_associated_cleaned.csv')
onetoone=pd.read_csv('/content/one_to_one_cleaned.csv')

# %%
k=skill_superskill[skill_superskill['super skill']=='data-visualization' ]

# %%
k[skill_superskill['1to1_question_number']==9]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Unnamed: 0           skill         super skill  1to1_question_number
# 134         134  Group box plot  data-visualization                     9

# %%
skill_question_issus={}
onetoone['skill'].value_counts().keys().tolist()
# Out:
# ['python',
#  'data-preprocessing',
#  'data-visualization',
#  'supervised-machine-learning',
#  'unsupervised-machine-learning']

# %%
skill_superskill_data_visualization=skill_superskill[skill_superskill['super skill']=='data-visualization']
onetoone_data_visualization=onetoone[onetoone['skill']=='data-visualization']

# %%
# !pip install autoplotter

# %%
onetoone_data_visualization
# Out:
#                                student id  ... question10
# 175  8c1fc1d5-e2b9-4c85-a9fc-87d6b225f996  ...          0
# 176  592359a2-db7e-4eb3-9a8f-c7c62ffa1866  ...          0
# 177  6aadae3d-eefb-415f-990c-7d4b6130c3fb  ...          0
# 178  724429a8-bd0d-4797-a4af-eb427f618ea9  ...          2
# 179  ff27a272-d123-4b8a-b681-f17fce758a74  ...          2
# 180  5807d177-0fd8-4bb0-82e3-a07ff403def0  ...          2
# 181  b367dfc4-a5f6-4fbb-8c05-2bd9b9992249  ...          0
# 182  479b6213-9157-4fc2-97bb-e2c886c76db9  ...          0
# 183  8e07b0d6-484c-4f07-b0b3-7b35f0d28035  ...          0
# 184  8fe1f65b-c9b9-4a4f-b09e-c43ba07ed002  ...          2
# 185  0df3fb25-997d-4333-ae57-f548288f009f  ...          2
# 186  aa54ebd6-e257-4f6a-bdc8-4cb2ca8314d9  ...          2
# 187  1f715742-6b1e-4edd-aafa-272ce476462d  ...          2
# 188  f50a9e3c-5679-4cb4-9310-fa94e03d1aef  ...          2
# 189  75c8dbe9-7ace-4429-b12c-ca86e55aef32  ...          2
# ...

# %%
import seaborn as sns
sns.boxplot( y=onetoone_data_visualization['score'] )
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# the scores are between 40% and 100% the median of scores taken  is 80%
#
# 1.   List item
# 2.   List item

# %%
import matplotlib.pyplot as plt 
questions1=onetoone_data_visualization.drop(['student id', 'skill','score'], axis=1)
questions=onetoone_data_visualization.drop(['student id', 'skill','score'], axis=1).sum()
questions.plot(kind='pie', subplots=True, figsize=(16,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4815961128>],
#       dtype=object)

# %%
List_0=pd.melt(questions1).groupby(["value","variable"])['variable'].count()[0].sort_values(ascending =False).head(3).keys().tolist()

# %%
for x in List_0:
  print(x)
# Out:
# question10
# question6
# question7

# %% [markdown]
# question 1 and question4 are the most questions with low understanding scores

# %%
questions1=onetoone_data_visualization.drop(['student id', 'skill','score'], axis=1)
mean=onetoone_data_visualization.drop(['student id', 'skill','score'], axis=1).mean()

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='value', hue='variable',data=pd.melt(questions1))

# %% [markdown]
# as we see here that the most difficult question are question:4,1,10,8

# %%
data_visualization_variable_value=pd.melt(questions1)
print (data_visualization_variable_value)
# Out:
#        variable  value
# 0    question 1      2
# 1    question 1      2
# 2    question 1      2
# 3    question 1      2
# 4    question 1      2
# ..          ...    ...
# 505  question10      0
# 506  question10      0
# 507  question10      0
# 508  question10      0
# 509  question10      2
#
# [510 rows x 2 columns]

# %%
q=[10,6,7]
for Q in q:
  print(k[k['1to1_question_number']==Q]['skill'].values)
# Out:
# ['Standardization']
# ['Histograms information']
# ['Correlation using Seaborn']
